# %%
import os
data_directory = "java_data_pickled/"
files = os.listdir(data_directory)
print(files[:1])
print(len(files))
# Out:
# ['feature_99764.pkl']
# 107

# %%
# Original source from following
# Edited by Young Seok Kim

# http://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html#sphx-glr-auto-examples-classification-plot-classifier-comparison-py
# Code source: Gaël Varoquaux
#              Andreas Müller
# Modified for documentation by Jaques Grobler
# License: BSD 3 clause
# 

import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

# %%
def run_models(X, y):
    h = .02  # step size in the mesh
    names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Gaussian Process",
             "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
             "Naive Bayes", "QDA"]
    
    classifiers = [
        KNeighborsClassifier(3),
        SVC(kernel="linear", C=0.025),
        SVC(gamma=2, C=1),
        GaussianProcessClassifier(1.0 * RBF(1.0)),
        DecisionTreeClassifier(max_depth=5),
        RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
        MLPClassifier(alpha=1),
        AdaBoostClassifier(),
        GaussianNB(),
        QuadraticDiscriminantAnalysis()
    ]    
    
    # Split test / train sets
    X_train, X_test, y_train, y_test = \
        train_test_split(X, y, test_size=.3, random_state=42)
        
    # Normalize datasets only based on train set
    Normalizer = StandardScaler()
    Normalizer.fit(X_train)
    X_train = Normalizer.transform(X_train)
    X_test = Normalizer.transform(X_test)

    accuracies = {} # classifier_name : accuracy
    # iterate over classifiers
    for name, clf in zip(names, classifiers):
        clf.fit(X_train, y_train)
        score = clf.score(X_test, y_test)
        print(name)
        print('accuracy : %.4f' % score)
        accuracies[name] = score
    
    return accuracies

# %%
# %%time
import pickle

best_model = ""
best_accuracy = 0.0
for file in files:
    print('-------------------------------------------------')
    with open(data_directory + file, "rb") as f:
        print(file)
        X, y = pickle.load(f)
        accuracies = run_models(X,y)
        for model_name, accuracy in accuracies.items():
            if best_accuracy < accuracy :
                best_accuracy = accuracy
                best_model = file + " " + model_name
print("Done!")
# Out:
# -------------------------------------------------
# feature_99764.pkl
# Nearest Neighbors
# accuracy : 0.8444
# Linear SVM
# accuracy : 0.4967
# RBF SVM
# accuracy : 0.8411
# Gaussian Process
# accuracy : 0.8510
# Decision Tree
# accuracy : 0.7500
# Random Forest
# accuracy : 0.6937
# Neural Net
# accuracy : 0.5811
# AdaBoost
# accuracy : 0.6871
# Naive Bayes
# accuracy : 0.5199
# QDA
# accuracy : 0.5513
# -------------------------------------------------
# feature_9474.pkl
# Nearest Neighbors
# accuracy : 0.8411
# Linear SVM
# accuracy : 0.5265
# RBF SVM
# accuracy : 0.8212
# Gaussian Process
# accuracy : 0.8228
# Decision Tree
# accuracy : 0.7417
# Random Forest
# accuracy : 0.6887
# Neural Net
# accuracy : 0.6424
# AdaBoost
# accuracy : 0.6474
# Naive Bayes
# accuracy : 0.5017
# QDA
# accuracy : 0.5861
# -------------------------------------------------
# feature_93083.pkl
# Nearest Neighbors
# accuracy : 0.8146
# Linear SVM
# accuracy : 0.5844
# RBF SVM
# accuracy : 0.8113
# Gaussian Process
# accuracy : 0.8228
# Decision Tree
# accuracy : 0.7152
# Random Forest
# accuracy : 0.7500
# Neural Net
# accuracy : 0.6474
# AdaBoost
# accuracy : 0.5033
# Naive Bayes
# accuracy : 0.6060
# QDA
# accuracy : 0.6209
# -------------------------------------------------
# feature_2969.pkl
# Nearest Neighbors
# accuracy : 0.9106
# Linear SVM
# accuracy : 0.6821
# RBF SVM
# accuracy : 0.9056
# Gaussian Process
# accuracy : 0.9106
# Decision Tree
# accuracy : 0.7368
# Random Forest
# accuracy : 0.7848
# Neural Net
# accuracy : 0.7252
# AdaBoost
# accuracy : 0.7185
# Naive Bayes
# accuracy : 0.6258
# QDA
# accuracy : 0.6672
# -------------------------------------------------
# feature_41478.pkl
# Nearest Neighbors
# accuracy : 0.9023
# Linear SVM
# accuracy : 0.6556
# RBF SVM
# accuracy : 0.9089
# Gaussian Process
# accuracy : 0.9089
# Decision Tree
# accuracy : 0.7219
# Random Forest
# accuracy : 0.7815
# Neural Net
# accuracy : 0.7318
# AdaBoost
# accuracy : 0.7202
# Naive Bayes
# accuracy : 0.6142
# QDA
# accuracy : 0.6854
# -------------------------------------------------
# feature_32156.pkl
# Nearest Neighbors
# accuracy : 0.8907
# Linear SVM
# accuracy : 0.6424
# RBF SVM
# accuracy : 0.8858
# Gaussian Process
# accuracy : 0.8891
# Decision Tree
# accuracy : 0.7202
# Random Forest
# accuracy : 0.7897
# Neural Net
# accuracy : 0.7599
# AdaBoost
# accuracy : 0.5513
# Naive Bayes
# accuracy : 0.6573
# QDA
# accuracy : 0.6987
# -------------------------------------------------
# feature_44285.pkl
# Nearest Neighbors
# accuracy : 0.8560
# Linear SVM
# accuracy : 0.6010
# RBF SVM
# accuracy : 0.8758
# Gaussian Process
# accuracy : 0.8825
# Decision Tree
# accuracy : 0.6904
# Random Forest
# accuracy : 0.7152
# Neural Net
# accuracy : 0.6689
# AdaBoost
# accuracy : 0.5149
# Naive Bayes
# accuracy : 0.6043
# QDA
# accuracy : 0.6424
# -------------------------------------------------
# feature_17166.pkl
# Nearest Neighbors
# accuracy : 0.8228
# Linear SVM
# accuracy : 0.5281
# RBF SVM
# accuracy : 0.8146
# Gaussian Process
# accuracy : 0.8195
# Decision Tree
# accuracy : 0.7450
# Random Forest
# accuracy : 0.6937
# Neural Net
# accuracy : 0.5894
# AdaBoost
# accuracy : 0.6325
# Naive Bayes
# accuracy : 0.5298
# QDA
# accuracy : 0.5662
# -------------------------------------------------
# feature_96427.pkl
# Nearest Neighbors
# accuracy : 0.8560
# Linear SVM
# accuracy : 0.6076
# RBF SVM
# accuracy : 0.8510
# Gaussian Process
# accuracy : 0.8560
# Decision Tree
# accuracy : 0.7252
# Random Forest
# accuracy : 0.7483
# Neural Net
# accuracy : 0.7202
# AdaBoost
# accuracy : 0.6540
# Naive Bayes
# accuracy : 0.6242
# QDA
# accuracy : 0.6722
# -------------------------------------------------
# feature_87207.pkl
# Nearest Neighbors
# accuracy : 0.8427
# Linear SVM
# accuracy : 0.6440
# RBF SVM
# accuracy : 0.8510
# Gaussian Process
# accuracy : 0.8709
# Decision Tree
# accuracy : 0.7881
# Random Forest
# accuracy : 0.7897
# Neural Net
# accuracy : 0.7798
# AdaBoost
# accuracy : 0.5563
# Naive Bayes
# accuracy : 0.6209
# QDA
# accuracy : 0.6805
# -------------------------------------------------
# feature_90703.pkl
# Nearest Neighbors
# accuracy : 0.8990
# Linear SVM
# accuracy : 0.6805
# RBF SVM
# accuracy : 0.8990
# Gaussian Process
# accuracy : 0.9007
# Decision Tree
# accuracy : 0.7550
# Random Forest
# accuracy : 0.7798
# Neural Net
# accuracy : 0.7136
# AdaBoost
# accuracy : 0.7583
# Naive Bayes
# accuracy : 0.6291
# QDA
# accuracy : 0.6722
# -------------------------------------------------
# feature_22067.pkl
# Nearest Neighbors
# accuracy : 0.8957
# Linear SVM
# accuracy : 0.7268
# RBF SVM
# accuracy : 0.8841
# Gaussian Process
# accuracy : 0.8891
# Decision Tree
# accuracy : 0.8046
# Random Forest
# accuracy : 0.8245
# Neural Net
# accuracy : 0.7550
# AdaBoost
# accuracy : 0.5149
# Naive Bayes
# accuracy : 0.6921
# QDA
# accuracy : 0.7169
# -------------------------------------------------
# feature_33423.pkl
# Nearest Neighbors
# accuracy : 0.8510
# Linear SVM
# accuracy : 0.6242
# RBF SVM
# accuracy : 0.8477
# Gaussian Process
# accuracy : 0.8477
# Decision Tree
# accuracy : 0.7053
# Random Forest
# accuracy : 0.7401
# Neural Net
# accuracy : 0.7152
# AdaBoost
# accuracy : 0.6407
# Naive Bayes
# accuracy : 0.6159
# QDA
# accuracy : 0.6639
# -------------------------------------------------
# feature_30337.pkl
# Nearest Neighbors
# accuracy : 0.8858
# Linear SVM
# accuracy : 0.6192
# RBF SVM
# accuracy : 0.8808
# Gaussian Process
# accuracy : 0.8775
# Decision Tree
# accuracy : 0.7119
# Random Forest
# accuracy : 0.7467
# Neural Net
# accuracy : 0.6589
# AdaBoost
# accuracy : 0.6871
# Naive Bayes
# accuracy : 0.5861
# QDA
# accuracy : 0.6556
# -------------------------------------------------
# feature_91226.pkl
# Nearest Neighbors
# accuracy : 0.9023
# Linear SVM
# accuracy : 0.6871
# RBF SVM
# accuracy : 0.8825
# Gaussian Process
# accuracy : 0.8957
# Decision Tree
# accuracy : 0.7483
# Random Forest
# accuracy : 0.7765
# Neural Net
# accuracy : 0.7748
# AdaBoost
# accuracy : 0.6242
# Naive Bayes
# accuracy : 0.6738
# QDA
# accuracy : 0.6987
# -------------------------------------------------
# feature_50995.pkl
# Nearest Neighbors
# accuracy : 0.8642
# Linear SVM
# accuracy : 0.5745
# RBF SVM
# accuracy : 0.8609
# Gaussian Process
# accuracy : 0.8609
# Decision Tree
# accuracy : 0.7384
# Random Forest
# accuracy : 0.7351
# Neural Net
# accuracy : 0.7368
# AdaBoost
# accuracy : 0.5613
# Naive Bayes
# accuracy : 0.5795
# QDA
# accuracy : 0.6490
# -------------------------------------------------
# feature_88849.pkl
# Nearest Neighbors
# accuracy : 0.8543
# Linear SVM
# accuracy : 0.6325
# RBF SVM
# accuracy : 0.8675
# Gaussian Process
# accuracy : 0.8576
# Decision Tree
# accuracy : 0.7732
# Random Forest
# accuracy : 0.7864
# Neural Net
# accuracy : 0.7003
# AdaBoost
# accuracy : 0.7351
# Naive Bayes
# accuracy : 0.6175
# QDA
# accuracy : 0.6573
# -------------------------------------------------
# feature_95409.pkl
# Nearest Neighbors
# accuracy : 0.8493
# Linear SVM
# accuracy : 0.6175
# RBF SVM
# accuracy : 0.8742
# Gaussian Process
# accuracy : 0.8791
# Decision Tree
# accuracy : 0.6904
# Random Forest
# accuracy : 0.7202
# Neural Net
# accuracy : 0.6838
# AdaBoost
# accuracy : 0.4983
# Naive Bayes
# accuracy : 0.6175
# QDA
# accuracy : 0.6424
# -------------------------------------------------
# feature_37779.pkl
# Nearest Neighbors
# accuracy : 0.8576
# Linear SVM
# accuracy : 0.6275
# RBF SVM
# accuracy : 0.8725
# Gaussian Process
# accuracy : 0.8874
# Decision Tree
# accuracy : 0.7517
# Random Forest
# accuracy : 0.7715
# Neural Net
# accuracy : 0.6970
# AdaBoost
# accuracy : 0.6639
# Naive Bayes
# accuracy : 0.6407
# QDA
# accuracy : 0.6440
# -------------------------------------------------
# feature_948.pkl
# Nearest Neighbors
# accuracy : 0.8411
# Linear SVM
# accuracy : 0.5977
# RBF SVM
# accuracy : 0.8328
# Gaussian Process
# accuracy : 0.8377
# Decision Tree
# accuracy : 0.6788
# Random Forest
# accuracy : 0.7152
# Neural Net
# accuracy : 0.6689
# AdaBoost
# accuracy : 0.6589
# Naive Bayes
# accuracy : 0.6109
# QDA
# accuracy : 0.6407
# -------------------------------------------------
# feature_58401.pkl
# Nearest Neighbors
# accuracy : 0.8808
# Linear SVM
# accuracy : 0.7053
# RBF SVM
# accuracy : 0.8974
# Gaussian Process
# accuracy : 0.9089
# Decision Tree
# accuracy : 0.7467
# Random Forest
# accuracy : 0.8311
# Neural Net
# accuracy : 0.7599
# AdaBoost
# accuracy : 0.7434
# Naive Bayes
# accuracy : 0.6871
# QDA
# accuracy : 0.7252
# -------------------------------------------------
# feature_62723.pkl
# Nearest Neighbors
# accuracy : 0.8626
# Linear SVM
# accuracy : 0.6341
# RBF SVM
# accuracy : 0.8394
# Gaussian Process
# accuracy : 0.8609
# Decision Tree
# accuracy : 0.7020
# Random Forest
# accuracy : 0.7384
# Neural Net
# accuracy : 0.7318
# AdaBoost
# accuracy : 0.5298
# Naive Bayes
# accuracy : 0.6507
# QDA
# accuracy : 0.6738
# -------------------------------------------------
# feature_72466.pkl
# Nearest Neighbors
# accuracy : 0.8907
# Linear SVM
# accuracy : 0.6457
# RBF SVM
# accuracy : 0.8775
# Gaussian Process
# accuracy : 0.8990
# Decision Tree
# accuracy : 0.7351
# Random Forest
# accuracy : 0.7599
# Neural Net
# accuracy : 0.7119
# AdaBoost
# accuracy : 0.7649
# Naive Bayes
# accuracy : 0.6060
# QDA
# accuracy : 0.6457
# -------------------------------------------------
# feature_95922.pkl
# Nearest Neighbors
# accuracy : 0.8990
# Linear SVM
# accuracy : 0.6805
# RBF SVM
# accuracy : 0.8990
# Gaussian Process
# accuracy : 0.9007
# Decision Tree
# accuracy : 0.7550
# Random Forest
# accuracy : 0.7599
# Neural Net
# accuracy : 0.7136
# AdaBoost
# accuracy : 0.7583
# Naive Bayes
# accuracy : 0.6291
# QDA
# accuracy : 0.6722
# -------------------------------------------------
# feature_14784.pkl
# Nearest Neighbors
# accuracy : 0.8609
# Linear SVM
# accuracy : 0.6639
# RBF SVM
# accuracy : 0.8609
# Gaussian Process
# accuracy : 0.8692
# Decision Tree
# accuracy : 0.7732
# Random Forest
# accuracy : 0.7467
# Neural Net
# accuracy : 0.7401
# AdaBoost
# accuracy : 0.6970
# Naive Bayes
# accuracy : 0.6672
# QDA
# accuracy : 0.6987
# -------------------------------------------------
# feature_68851.pkl
# Nearest Neighbors
# accuracy : 0.8858
# Linear SVM
# accuracy : 0.7119
# RBF SVM
# accuracy : 0.8907
# Gaussian Process
# accuracy : 0.8974
# Decision Tree
# accuracy : 0.7666
# Random Forest
# accuracy : 0.8030
# Neural Net
# accuracy : 0.7384
# AdaBoost
# accuracy : 0.7947
# Naive Bayes
# accuracy : 0.6954
# QDA
# accuracy : 0.7003
# -------------------------------------------------
# feature_8246.pkl
# Nearest Neighbors
# accuracy : 0.8990
# Linear SVM
# accuracy : 0.7136
# RBF SVM
# accuracy : 0.9073
# Gaussian Process
# accuracy : 0.9040
# Decision Tree
# accuracy : 0.8129
# Random Forest
# accuracy : 0.8096
# Neural Net
# accuracy : 0.7202
# AdaBoost
# accuracy : 0.5613
# Naive Bayes
# accuracy : 0.6987
# QDA
# accuracy : 0.6937
# -------------------------------------------------
# feature_84030.pkl
# Nearest Neighbors
# accuracy : 0.9089
# Linear SVM
# accuracy : 0.7020
# RBF SVM
# accuracy : 0.8957
# Gaussian Process
# accuracy : 0.9123
# Decision Tree
# accuracy : 0.7682
# Random Forest
# accuracy : 0.7765
# Neural Net
# accuracy : 0.7550
# AdaBoost
# accuracy : 0.6242
# Naive Bayes
# accuracy : 0.6656
# QDA
# accuracy : 0.6954
# -------------------------------------------------
# feature_54134.pkl
# Nearest Neighbors
# accuracy : 0.8560
# Linear SVM
# accuracy : 0.5828
# RBF SVM
# accuracy : 0.8609
# Gaussian Process
# accuracy : 0.8990
# Decision Tree
# accuracy : 0.7699
# Random Forest
# accuracy : 0.7401
# Neural Net
# accuracy : 0.6623
# AdaBoost
# accuracy : 0.5182
# Naive Bayes
# accuracy : 0.5298
# QDA
# accuracy : 0.5811
# -------------------------------------------------
# feature_95329.pkl
# Nearest Neighbors
# accuracy : 0.8841
# Linear SVM
# accuracy : 0.6076
# RBF SVM
# accuracy : 0.8825
# Gaussian Process
# accuracy : 0.8907
# Decision Tree
# accuracy : 0.7086
# Random Forest
# accuracy : 0.7086
# Neural Net
# accuracy : 0.6755
# AdaBoost
# accuracy : 0.6523
# Naive Bayes
# accuracy : 0.5894
# QDA
# accuracy : 0.6474
# -------------------------------------------------
# feature_70645.pkl
# Nearest Neighbors
# accuracy : 0.8427
# Linear SVM
# accuracy : 0.6010
# RBF SVM
# accuracy : 0.8692
# Gaussian Process
# accuracy : 0.8593
# Decision Tree
# accuracy : 0.6937
# Random Forest
# accuracy : 0.7533
# Neural Net
# accuracy : 0.6788
# AdaBoost
# accuracy : 0.6242
# Naive Bayes
# accuracy : 0.5960
# QDA
# accuracy : 0.6457
# -------------------------------------------------
# feature_97944.pkl
# Nearest Neighbors
# accuracy : 0.8808
# Linear SVM
# accuracy : 0.6225
# RBF SVM
# accuracy : 0.8791
# Gaussian Process
# accuracy : 0.8808
# Decision Tree
# accuracy : 0.7831
# Random Forest
# accuracy : 0.7831
# Neural Net
# accuracy : 0.7550
# AdaBoost
# accuracy : 0.7036
# Naive Bayes
# accuracy : 0.6275
# QDA
# accuracy : 0.6788
# -------------------------------------------------
# feature_96259.pkl
# Nearest Neighbors
# accuracy : 0.8924
# Linear SVM
# accuracy : 0.7384
# RBF SVM
# accuracy : 0.8841
# Gaussian Process
# accuracy : 0.9007
# Decision Tree
# accuracy : 0.8328
# Random Forest
# accuracy : 0.8377
# Neural Net
# accuracy : 0.7666
# AdaBoost
# accuracy : 0.7351
# Naive Bayes
# accuracy : 0.7053
# QDA
# accuracy : 0.7467
# -------------------------------------------------
# feature_53151.pkl
# Nearest Neighbors
# accuracy : 0.8593
# Linear SVM
# accuracy : 0.6175
# RBF SVM
# accuracy : 0.8642
# Gaussian Process
# accuracy : 0.8742
# Decision Tree
# accuracy : 0.6821
# Random Forest
# accuracy : 0.7483
# Neural Net
# accuracy : 0.6871
# AdaBoost
# accuracy : 0.6805
# Naive Bayes
# accuracy : 0.6060
# QDA
# accuracy : 0.6490
# -------------------------------------------------
# feature_4896.pkl
# Nearest Neighbors
# accuracy : 0.9040
# Linear SVM
# accuracy : 0.6656
# RBF SVM
# accuracy : 0.9040
# Gaussian Process
# accuracy : 0.9007
# Decision Tree
# accuracy : 0.7666
# Random Forest
# accuracy : 0.8013
# Neural Net
# accuracy : 0.7467
# AdaBoost
# accuracy : 0.7881
# Naive Bayes
# accuracy : 0.6722
# QDA
# accuracy : 0.7152
# -------------------------------------------------
# feature_15934.pkl
# Nearest Neighbors
# accuracy : 0.8791
# Linear SVM
# accuracy : 0.5844
# RBF SVM
# accuracy : 0.8940
# Gaussian Process
# accuracy : 0.8974
# Decision Tree
# accuracy : 0.7881
# Random Forest
# accuracy : 0.7930
# Neural Net
# accuracy : 0.7351
# AdaBoost
# accuracy : 0.6871
# Naive Bayes
# accuracy : 0.5927
# QDA
# accuracy : 0.5944
# -------------------------------------------------
# feature_35730.pkl
# Nearest Neighbors
# accuracy : 0.8775
# Linear SVM
# accuracy : 0.6738
# RBF SVM
# accuracy : 0.8891
# Gaussian Process
# accuracy : 0.8808
# Decision Tree
# accuracy : 0.7748
# Random Forest
# accuracy : 0.7616
# Neural Net
# accuracy : 0.7384
# AdaBoost
# accuracy : 0.6838
# Naive Bayes
# accuracy : 0.6887
# QDA
# accuracy : 0.6970
# -------------------------------------------------
# feature_70803.pkl
# Nearest Neighbors
# accuracy : 0.8957
# Linear SVM
# accuracy : 0.6887
# RBF SVM
# accuracy : 0.8957
# Gaussian Process
# accuracy : 0.9123
# Decision Tree
# accuracy : 0.7732
# Random Forest
# accuracy : 0.7947
# Neural Net
# accuracy : 0.7384
# AdaBoost
# accuracy : 0.6854
# Naive Bayes
# accuracy : 0.6689
# QDA
# accuracy : 0.6887
# -------------------------------------------------
# feature_59944.pkl
# Nearest Neighbors
# accuracy : 0.8609
# Linear SVM
# accuracy : 0.5629
# RBF SVM
# accuracy : 0.8526
# Gaussian Process
# accuracy : 0.8642
# Decision Tree
# accuracy : 0.7748
# Random Forest
# accuracy : 0.7666
# Neural Net
# accuracy : 0.6705
# AdaBoost
# accuracy : 0.5348
# Naive Bayes
# accuracy : 0.6010
# QDA
# accuracy : 0.5679
# -------------------------------------------------
# feature_67216.pkl
# Nearest Neighbors
# accuracy : 0.8626
# Linear SVM
# accuracy : 0.5397
# RBF SVM
# accuracy : 0.8742
# Gaussian Process
# accuracy : 0.8775
# Decision Tree
# accuracy : 0.7682
# Random Forest
# accuracy : 0.7765
# Neural Net
# accuracy : 0.7219
# AdaBoost
# accuracy : 0.5017
# Naive Bayes
# accuracy : 0.5596
# QDA
# accuracy : 0.5480
# -------------------------------------------------
# feature_15045.pkl
# Nearest Neighbors
# accuracy : 0.8940
# Linear SVM
# accuracy : 0.6970
# RBF SVM
# accuracy : 0.8841
# Gaussian Process
# accuracy : 0.8957
# Decision Tree
# accuracy : 0.7550
# Random Forest
# accuracy : 0.8079
# Neural Net
# accuracy : 0.7500
# AdaBoost
# accuracy : 0.6126
# Naive Bayes
# accuracy : 0.6805
# QDA
# accuracy : 0.7318
# -------------------------------------------------
# feature_94731.pkl
# Nearest Neighbors
# accuracy : 0.8394
# Linear SVM
# accuracy : 0.6126
# RBF SVM
# accuracy : 0.8477
# Gaussian Process
# accuracy : 0.8477
# Decision Tree
# accuracy : 0.7301
# Random Forest
# accuracy : 0.7699
# Neural Net
# accuracy : 0.7086
# AdaBoost
# accuracy : 0.6606
# Naive Bayes
# accuracy : 0.6358
# QDA
# accuracy : 0.6755
# -------------------------------------------------
# feature_98065.pkl
# Nearest Neighbors
# accuracy : 0.8891
# Linear SVM
# accuracy : 0.6540
# RBF SVM
# accuracy : 0.8692
# Gaussian Process
# accuracy : 0.8709
# Decision Tree
# accuracy : 0.6937
# Random Forest
# accuracy : 0.7334
# Neural Net
# accuracy : 0.7566
# AdaBoost
# accuracy : 0.5662
# Naive Bayes
# accuracy : 0.6424
# QDA
# accuracy : 0.6672
# -------------------------------------------------
# feature_91886.pkl
# Nearest Neighbors
# accuracy : 0.8311
# Linear SVM
# accuracy : 0.4685
# RBF SVM
# accuracy : 0.8129
# Gaussian Process
# accuracy : 0.8361
# Decision Tree
# accuracy : 0.7318
# Random Forest
# accuracy : 0.7185
# Neural Net
# accuracy : 0.6142
# AdaBoost
# accuracy : 0.6556
# Naive Bayes
# accuracy : 0.5149
# QDA
# accuracy : 0.5695
# -------------------------------------------------
# feature_87086.pkl
# Nearest Neighbors
# accuracy : 0.9172
# Linear SVM
# accuracy : 0.6788
# RBF SVM
# accuracy : 0.9073
# Gaussian Process
# accuracy : 0.9056
# Decision Tree
# accuracy : 0.7649
# Random Forest
# accuracy : 0.8278
# Neural Net
# accuracy : 0.7318
# AdaBoost
# accuracy : 0.7930
# Naive Bayes
# accuracy : 0.6490
# QDA
# accuracy : 0.7053
# -------------------------------------------------
# feature_90151.pkl
# Nearest Neighbors
# accuracy : 0.8825
# Linear SVM
# accuracy : 0.6126
# RBF SVM
# accuracy : 0.8725
# Gaussian Process
# accuracy : 0.8891
# Decision Tree
# accuracy : 0.6904
# Random Forest
# accuracy : 0.7450
# Neural Net
# accuracy : 0.6954
# AdaBoost
# accuracy : 0.6755
# Naive Bayes
# accuracy : 0.6026
# QDA
# accuracy : 0.6325
# -------------------------------------------------
# feature_5245.pkl
# Nearest Neighbors
# accuracy : 0.8593
# Linear SVM
# accuracy : 0.5960
# RBF SVM
# accuracy : 0.8709
# Gaussian Process
# accuracy : 0.8692
# Decision Tree
# accuracy : 0.7632
# Random Forest
# accuracy : 0.7897
# Neural Net
# accuracy : 0.7384
# AdaBoost
# accuracy : 0.7285
# Naive Bayes
# accuracy : 0.5944
# QDA
# accuracy : 0.6589
# -------------------------------------------------
# feature_55127.pkl
# Nearest Neighbors
# accuracy : 0.9172
# Linear SVM
# accuracy : 0.6954
# RBF SVM
# accuracy : 0.9007
# Gaussian Process
# accuracy : 0.9172
# Decision Tree
# accuracy : 0.7666
# Random Forest
# accuracy : 0.8344
# Neural Net
# accuracy : 0.7616
# AdaBoost
# accuracy : 0.6175
# Naive Bayes
# accuracy : 0.6689
# QDA
# accuracy : 0.6921
# -------------------------------------------------
# feature_42312.pkl
# Nearest Neighbors
# accuracy : 0.9089
# Linear SVM
# accuracy : 0.6772
# RBF SVM
# accuracy : 0.9023
# Gaussian Process
# accuracy : 0.9007
# Decision Tree
# accuracy : 0.7566
# Random Forest
# accuracy : 0.7517
# Neural Net
# accuracy : 0.7169
# AdaBoost
# accuracy : 0.7285
# Naive Bayes
# accuracy : 0.6275
# QDA
# accuracy : 0.6755
# -------------------------------------------------
# feature_32281.pkl
# Nearest Neighbors
# accuracy : 0.8411
# Linear SVM
# accuracy : 0.6076
# RBF SVM
# accuracy : 0.8510
# Gaussian Process
# accuracy : 0.8593
# Decision Tree
# accuracy : 0.6821
# Random Forest
# accuracy : 0.7318
# Neural Net
# accuracy : 0.6705
# AdaBoost
# accuracy : 0.4967
# Naive Bayes
# accuracy : 0.5877
# QDA
# accuracy : 0.6192
# -------------------------------------------------
# feature_32600.pkl
# Nearest Neighbors
# accuracy : 0.8874
# Linear SVM
# accuracy : 0.7020
# RBF SVM
# accuracy : 0.9023
# Gaussian Process
# accuracy : 0.9007
# Decision Tree
# accuracy : 0.7533
# Random Forest
# accuracy : 0.7831
# Neural Net
# accuracy : 0.7368
# AdaBoost
# accuracy : 0.6175
# Naive Bayes
# accuracy : 0.6805
# QDA
# accuracy : 0.7318
# -------------------------------------------------
# feature_43315.pkl
# Nearest Neighbors
# accuracy : 0.9040
# Linear SVM
# accuracy : 0.6854
# RBF SVM
# accuracy : 0.9007
# Gaussian Process
# accuracy : 0.9073
# Decision Tree
# accuracy : 0.7566
# Random Forest
# accuracy : 0.7616
# Neural Net
# accuracy : 0.7152
# AdaBoost
# accuracy : 0.7152
# Naive Bayes
# accuracy : 0.6142
# QDA
# accuracy : 0.6672
# -------------------------------------------------
# feature_16259.pkl
# Nearest Neighbors
# accuracy : 0.8709
# Linear SVM
# accuracy : 0.6490
# RBF SVM
# accuracy : 0.8593
# Gaussian Process
# accuracy : 0.8609
# Decision Tree
# accuracy : 0.7285
# Random Forest
# accuracy : 0.7500
# Neural Net
# accuracy : 0.6523
# AdaBoost
# accuracy : 0.6987
# Naive Bayes
# accuracy : 0.6225
# QDA
# accuracy : 0.6308
# -------------------------------------------------
# feature_35979.pkl
# Nearest Neighbors
# accuracy : 0.8394
# Linear SVM
# accuracy : 0.5861
# RBF SVM
# accuracy : 0.8427
# Gaussian Process
# accuracy : 0.8526
# Decision Tree
# accuracy : 0.7103
# Random Forest
# accuracy : 0.7252
# Neural Net
# accuracy : 0.6623
# AdaBoost
# accuracy : 0.4669
# Naive Bayes
# accuracy : 0.5828
# QDA
# accuracy : 0.6258
# -------------------------------------------------
# feature_86874.pkl
# Nearest Neighbors
# accuracy : 0.8113
# Linear SVM
# accuracy : 0.6175
# RBF SVM
# accuracy : 0.8311
# Gaussian Process
# accuracy : 0.8328
# Decision Tree
# accuracy : 0.7732
# Random Forest
# accuracy : 0.7235
# Neural Net
# accuracy : 0.6871
# AdaBoost
# accuracy : 0.5248
# Naive Bayes
# accuracy : 0.6076
# QDA
# accuracy : 0.6573
# -------------------------------------------------
# feature_94392.pkl
# Nearest Neighbors
# accuracy : 0.8891
# Linear SVM
# accuracy : 0.7169
# RBF SVM
# accuracy : 0.8924
# Gaussian Process
# accuracy : 0.8957
# Decision Tree
# accuracy : 0.7682
# Random Forest
# accuracy : 0.7997
# Neural Net
# accuracy : 0.7185
# AdaBoost
# accuracy : 0.4901
# Naive Bayes
# accuracy : 0.6821
# QDA
# accuracy : 0.6871
# -------------------------------------------------
# feature_21266.pkl
# Nearest Neighbors
# accuracy : 0.9106
# Linear SVM
# accuracy : 0.6887
# RBF SVM
# accuracy : 0.9007
# Gaussian Process
# accuracy : 0.8974
# Decision Tree
# accuracy : 0.7649
# Random Forest
# accuracy : 0.8030
# Neural Net
# accuracy : 0.7268
# AdaBoost
# accuracy : 0.7533
# Naive Bayes
# accuracy : 0.6623
# QDA
# accuracy : 0.6937
# -------------------------------------------------
# feature_20325.pkl
# Nearest Neighbors
# accuracy : 0.8940
# Linear SVM
# accuracy : 0.5513
# RBF SVM
# accuracy : 0.8576
# Gaussian Process
# accuracy : 0.8709
# Decision Tree
# accuracy : 0.7086
# Random Forest
# accuracy : 0.7119
# Neural Net
# accuracy : 0.6225
# AdaBoost
# accuracy : 0.4685
# Naive Bayes
# accuracy : 0.5149
# QDA
# accuracy : 0.5613
# -------------------------------------------------
# feature_42419.pkl
# Nearest Neighbors
# accuracy : 0.8974
# Linear SVM
# accuracy : 0.6689
# RBF SVM
# accuracy : 0.8940
# Gaussian Process
# accuracy : 0.9023
# Decision Tree
# accuracy : 0.7401
# Random Forest
# accuracy : 0.7682
# Neural Net
# accuracy : 0.7103
# AdaBoost
# accuracy : 0.7550
# Naive Bayes
# accuracy : 0.6209
# QDA
# accuracy : 0.6772
# -------------------------------------------------
# feature_65199.pkl
# Nearest Neighbors
# accuracy : 0.8311
# Linear SVM
# accuracy : 0.5977
# RBF SVM
# accuracy : 0.8344
# Gaussian Process
# accuracy : 0.8377
# Decision Tree
# accuracy : 0.7152
# Random Forest
# accuracy : 0.7467
# Neural Net
# accuracy : 0.6954
# AdaBoost
# accuracy : 0.6954
# Naive Bayes
# accuracy : 0.6192
# QDA
# accuracy : 0.6291
# -------------------------------------------------
# feature_52855.pkl
# Nearest Neighbors
# accuracy : 0.8659
# Linear SVM
# accuracy : 0.6209
# RBF SVM
# accuracy : 0.8692
# Gaussian Process
# accuracy : 0.8725
# Decision Tree
# accuracy : 0.7368
# Random Forest
# accuracy : 0.7450
# Neural Net
# accuracy : 0.7334
# AdaBoost
# accuracy : 0.7583
# Naive Bayes
# accuracy : 0.6407
# QDA
# accuracy : 0.6556
# -------------------------------------------------
# feature_51469.pkl
# Nearest Neighbors
# accuracy : 0.8874
# Linear SVM
# accuracy : 0.6474
# RBF SVM
# accuracy : 0.8808
# Gaussian Process
# accuracy : 0.8907
# Decision Tree
# accuracy : 0.7914
# Random Forest
# accuracy : 0.7682
# Neural Net
# accuracy : 0.7136
# AdaBoost
# accuracy : 0.7649
# Naive Bayes
# accuracy : 0.5679
# QDA
# accuracy : 0.6540
# -------------------------------------------------
# feature_97988.pkl
# Nearest Neighbors
# accuracy : 0.8874
# Linear SVM
# accuracy : 0.6010
# RBF SVM
# accuracy : 0.8576
# Gaussian Process
# accuracy : 0.8858
# Decision Tree
# accuracy : 0.6838
# Random Forest
# accuracy : 0.7235
# Neural Net
# accuracy : 0.6838
# AdaBoost
# accuracy : 0.6474
# Naive Bayes
# accuracy : 0.6159
# QDA
# accuracy : 0.6474
# -------------------------------------------------
# feature_5067.pkl
# Nearest Neighbors
# accuracy : 0.8593
# Linear SVM
# accuracy : 0.6175
# RBF SVM
# accuracy : 0.8493
# Gaussian Process
# accuracy : 0.8593
# Decision Tree
# accuracy : 0.6838
# Random Forest
# accuracy : 0.7467
# Neural Net
# accuracy : 0.6854
# AdaBoost
# accuracy : 0.6937
# Naive Bayes
# accuracy : 0.6159
# QDA
# accuracy : 0.6275
# -------------------------------------------------
# feature_62254.pkl
# Nearest Neighbors
# accuracy : 0.8245
# Linear SVM
# accuracy : 0.5695
# RBF SVM
# accuracy : 0.7897
# Gaussian Process
# accuracy : 0.8344
# Decision Tree
# accuracy : 0.7268
# Random Forest
# accuracy : 0.6838
# Neural Net
# accuracy : 0.5977
# AdaBoost
# accuracy : 0.6838
# Naive Bayes
# accuracy : 0.5248
# QDA
# accuracy : 0.5414
# -------------------------------------------------
# feature_98533.pkl
# Nearest Neighbors
# accuracy : 0.9106
# Linear SVM
# accuracy : 0.7086
# RBF SVM
# accuracy : 0.9040
# Gaussian Process
# accuracy : 0.9172
# Decision Tree
# accuracy : 0.7616
# Random Forest
# accuracy : 0.7748
# Neural Net
# accuracy : 0.7334
# AdaBoost
# accuracy : 0.7169
# Naive Bayes
# accuracy : 0.6738
# QDA
# accuracy : 0.6954
# -------------------------------------------------
# feature_38559.pkl
# Nearest Neighbors
# accuracy : 0.8725
# Linear SVM
# accuracy : 0.5513
# RBF SVM
# accuracy : 0.8891
# Gaussian Process
# accuracy : 0.8775
# Decision Tree
# accuracy : 0.7219
# Random Forest
# accuracy : 0.7831
# Neural Net
# accuracy : 0.6805
# AdaBoost
# accuracy : 0.6821
# Naive Bayes
# accuracy : 0.5579
# QDA
# accuracy : 0.5927
# -------------------------------------------------
# feature_16853.pkl
# Nearest Neighbors
# accuracy : 0.8427
# Linear SVM
# accuracy : 0.6109
# RBF SVM
# accuracy : 0.8493
# Gaussian Process
# accuracy : 0.8477
# Decision Tree
# accuracy : 0.7434
# Random Forest
# accuracy : 0.7219
# Neural Net
# accuracy : 0.7252
# AdaBoost
# accuracy : 0.6606
# Naive Bayes
# accuracy : 0.6159
# QDA
# accuracy : 0.6540
# -------------------------------------------------
# feature_69338.pkl
# Nearest Neighbors
# accuracy : 0.9156
# Linear SVM
# accuracy : 0.6639
# RBF SVM
# accuracy : 0.9056
# Gaussian Process
# accuracy : 0.9139
# Decision Tree
# accuracy : 0.7566
# Random Forest
# accuracy : 0.7715
# Neural Net
# accuracy : 0.7517
# AdaBoost
# accuracy : 0.7583
# Naive Bayes
# accuracy : 0.6805
# QDA
# accuracy : 0.7169
# -------------------------------------------------
# feature_23944.pkl
# Nearest Neighbors
# accuracy : 0.8228
# Linear SVM
# accuracy : 0.5116
# RBF SVM
# accuracy : 0.8013
# Gaussian Process
# accuracy : 0.8212
# Decision Tree
# accuracy : 0.7070
# Random Forest
# accuracy : 0.7434
# Neural Net
# accuracy : 0.5480
# AdaBoost
# accuracy : 0.4768
# Naive Bayes
# accuracy : 0.5265
# QDA
# accuracy : 0.5497
# -------------------------------------------------
# feature_44538.pkl
# Nearest Neighbors
# accuracy : 0.8560
# Linear SVM
# accuracy : 0.6275
# RBF SVM
# accuracy : 0.8493
# Gaussian Process
# accuracy : 0.8609
# Decision Tree
# accuracy : 0.7020
# Random Forest
# accuracy : 0.7384
# Neural Net
# accuracy : 0.6755
# AdaBoost
# accuracy : 0.6623
# Naive Bayes
# accuracy : 0.6076
# QDA
# accuracy : 0.6391
# -------------------------------------------------
# feature_59847.pkl
# Nearest Neighbors
# accuracy : 0.8825
# Linear SVM
# accuracy : 0.6490
# RBF SVM
# accuracy : 0.8907
# Gaussian Process
# accuracy : 0.8891
# Decision Tree
# accuracy : 0.7434
# Random Forest
# accuracy : 0.7632
# Neural Net
# accuracy : 0.6805
# AdaBoost
# accuracy : 0.6722
# Naive Bayes
# accuracy : 0.6424
# QDA
# accuracy : 0.6540
# -------------------------------------------------
# feature_9320.pkl
# Nearest Neighbors
# accuracy : 0.8990
# Linear SVM
# accuracy : 0.7103
# RBF SVM
# accuracy : 0.8957
# Gaussian Process
# accuracy : 0.9123
# Decision Tree
# accuracy : 0.7715
# Random Forest
# accuracy : 0.8063
# Neural Net
# accuracy : 0.7599
# AdaBoost
# accuracy : 0.7980
# Naive Bayes
# accuracy : 0.6987
# QDA
# accuracy : 0.7351
# -------------------------------------------------
# feature_43075.pkl
# Nearest Neighbors
# accuracy : 0.8907
# Linear SVM
# accuracy : 0.6457
# RBF SVM
# accuracy : 0.8775
# Gaussian Process
# accuracy : 0.8974
# Decision Tree
# accuracy : 0.7351
# Random Forest
# accuracy : 0.7930
# Neural Net
# accuracy : 0.7152
# AdaBoost
# accuracy : 0.7649
# Naive Bayes
# accuracy : 0.6060
# QDA
# accuracy : 0.6457
# -------------------------------------------------
# feature_15696.pkl
# Nearest Neighbors
# accuracy : 0.8990
# Linear SVM
# accuracy : 0.6887
# RBF SVM
# accuracy : 0.8874
# Gaussian Process
# accuracy : 0.9073
# Decision Tree
# accuracy : 0.7831
# Random Forest
# accuracy : 0.8013
# Neural Net
# accuracy : 0.7533
# AdaBoost
# accuracy : 0.5199
# Naive Bayes
# accuracy : 0.6407
# QDA
# accuracy : 0.6904
# -------------------------------------------------
# feature_406.pkl
# Nearest Neighbors
# accuracy : 0.9040
# Linear SVM
# accuracy : 0.6738
# RBF SVM
# accuracy : 0.8957
# Gaussian Process
# accuracy : 0.8990
# Decision Tree
# accuracy : 0.7798
# Random Forest
# accuracy : 0.7964
# Neural Net
# accuracy : 0.7202
# AdaBoost
# accuracy : 0.7500
# Naive Bayes
# accuracy : 0.6391
# QDA
# accuracy : 0.6722
# -------------------------------------------------
# feature_77973.pkl
# Nearest Neighbors
# accuracy : 0.8576
# Linear SVM
# accuracy : 0.5877
# RBF SVM
# accuracy : 0.8427
# Gaussian Process
# accuracy : 0.8642
# Decision Tree
# accuracy : 0.7666
# Random Forest
# accuracy : 0.7136
# Neural Net
# accuracy : 0.7020
# AdaBoost
# accuracy : 0.6788
# Naive Bayes
# accuracy : 0.6043
# QDA
# accuracy : 0.6374
# -------------------------------------------------
# feature_1202.pkl
# Nearest Neighbors
# accuracy : 0.8344
# Linear SVM
# accuracy : 0.6093
# RBF SVM
# accuracy : 0.8460
# Gaussian Process
# accuracy : 0.8477
# Decision Tree
# accuracy : 0.7086
# Random Forest
# accuracy : 0.7467
# Neural Net
# accuracy : 0.6921
# AdaBoost
# accuracy : 0.5017
# Naive Bayes
# accuracy : 0.6126
# QDA
# accuracy : 0.6374
# -------------------------------------------------
# feature_12792.pkl
# Nearest Neighbors
# accuracy : 0.8891
# Linear SVM
# accuracy : 0.6954
# RBF SVM
# accuracy : 0.9007
# Gaussian Process
# accuracy : 0.9007
# Decision Tree
# accuracy : 0.7815
# Random Forest
# accuracy : 0.8228
# Neural Net
# accuracy : 0.7334
# AdaBoost
# accuracy : 0.6325
# Naive Bayes
# accuracy : 0.6755
# QDA
# accuracy : 0.7036
# -------------------------------------------------
# feature_10269.pkl
# Nearest Neighbors
# accuracy : 0.8460
# Linear SVM
# accuracy : 0.5911
# RBF SVM
# accuracy : 0.8510
# Gaussian Process
# accuracy : 0.8576
# Decision Tree
# accuracy : 0.6921
# Random Forest
# accuracy : 0.7649
# Neural Net
# accuracy : 0.6573
# AdaBoost
# accuracy : 0.6606
# Naive Bayes
# accuracy : 0.5265
# QDA
# accuracy : 0.6060
# -------------------------------------------------
# feature_59947.pkl
# Nearest Neighbors
# accuracy : 0.9007
# Linear SVM
# accuracy : 0.6871
# RBF SVM
# accuracy : 0.8990
# Gaussian Process
# accuracy : 0.9073
# Decision Tree
# accuracy : 0.7616
# Random Forest
# accuracy : 0.7632
# Neural Net
# accuracy : 0.7252
# AdaBoost
# accuracy : 0.6159
# Naive Bayes
# accuracy : 0.6738
# QDA
# accuracy : 0.7036
# -------------------------------------------------
# feature_65539.pkl
# Nearest Neighbors
# accuracy : 0.8957
# Linear SVM
# accuracy : 0.6937
# RBF SVM
# accuracy : 0.8940
# Gaussian Process
# accuracy : 0.9007
# Decision Tree
# accuracy : 0.7748
# Random Forest
# accuracy : 0.8245
# Neural Net
# accuracy : 0.7550
# AdaBoost
# accuracy : 0.5993
# Naive Bayes
# accuracy : 0.6755
# QDA
# accuracy : 0.7036
# -------------------------------------------------
# feature_26404.pkl
# Nearest Neighbors
# accuracy : 0.8427
# Linear SVM
# accuracy : 0.6325
# RBF SVM
# accuracy : 0.8543
# Gaussian Process
# accuracy : 0.8510
# Decision Tree
# accuracy : 0.7384
# Random Forest
# accuracy : 0.7334
# Neural Net
# accuracy : 0.6854
# AdaBoost
# accuracy : 0.4619
# Naive Bayes
# accuracy : 0.5993
# QDA
# accuracy : 0.6043
# -------------------------------------------------
# feature_69037.pkl
# Nearest Neighbors
# accuracy : 0.8609
# Linear SVM
# accuracy : 0.6424
# RBF SVM
# accuracy : 0.8642
# Gaussian Process
# accuracy : 0.8692
# Decision Tree
# accuracy : 0.7682
# Random Forest
# accuracy : 0.7765
# Neural Net
# accuracy : 0.7318
# AdaBoost
# accuracy : 0.5546
# Naive Bayes
# accuracy : 0.6440
# QDA
# accuracy : 0.6705
# -------------------------------------------------
# feature_68161.pkl
# Nearest Neighbors
# accuracy : 0.8626
# Linear SVM
# accuracy : 0.6474
# RBF SVM
# accuracy : 0.8675
# Gaussian Process
# accuracy : 0.8825
# Decision Tree
# accuracy : 0.7483
# Random Forest
# accuracy : 0.7682
# Neural Net
# accuracy : 0.7185
# AdaBoost
# accuracy : 0.7086
# Naive Bayes
# accuracy : 0.6457
# QDA
# accuracy : 0.6838
# -------------------------------------------------
# feature_74214.pkl
# Nearest Neighbors
# accuracy : 0.8907
# Linear SVM
# accuracy : 0.6457
# RBF SVM
# accuracy : 0.8775
# Gaussian Process
# accuracy : 0.8990
# Decision Tree
# accuracy : 0.7351
# Random Forest
# accuracy : 0.7666
# Neural Net
# accuracy : 0.7103
# AdaBoost
# accuracy : 0.7649
# Naive Bayes
# accuracy : 0.6060
# QDA
# accuracy : 0.6457
# -------------------------------------------------
# feature_46481.pkl
# Nearest Neighbors
# accuracy : 0.8858
# Linear SVM
# accuracy : 0.6242
# RBF SVM
# accuracy : 0.8841
# Gaussian Process
# accuracy : 0.8974
# Decision Tree
# accuracy : 0.7550
# Random Forest
# accuracy : 0.8129
# Neural Net
# accuracy : 0.7450
# AdaBoost
# accuracy : 0.5861
# Naive Bayes
# accuracy : 0.6126
# QDA
# accuracy : 0.6142
# -------------------------------------------------
# feature_40777.pkl
# Nearest Neighbors
# accuracy : 0.9040
# Linear SVM
# accuracy : 0.7086
# RBF SVM
# accuracy : 0.8907
# Gaussian Process
# accuracy : 0.9007
# Decision Tree
# accuracy : 0.7483
# Random Forest
# accuracy : 0.8096
# Neural Net
# accuracy : 0.7715
# AdaBoost
# accuracy : 0.6109
# Naive Bayes
# accuracy : 0.6788
# QDA
# accuracy : 0.7136
# -------------------------------------------------
# feature_97367.pkl
# Nearest Neighbors
# accuracy : 0.8593
# Linear SVM
# accuracy : 0.6407
# RBF SVM
# accuracy : 0.8858
# Gaussian Process
# accuracy : 0.8907
# Decision Tree
# accuracy : 0.6987
# Random Forest
# accuracy : 0.7368
# Neural Net
# accuracy : 0.6854
# AdaBoost
# accuracy : 0.6887
# Naive Bayes
# accuracy : 0.5679
# QDA
# accuracy : 0.6209
# -------------------------------------------------
# feature_83891.pkl
# Nearest Neighbors
# accuracy : 0.8179
# Linear SVM
# accuracy : 0.5199
# RBF SVM
# accuracy : 0.8063
# Gaussian Process
# accuracy : 0.8262
# Decision Tree
# accuracy : 0.7070
# Random Forest
# accuracy : 0.7434
# Neural Net
# accuracy : 0.5811
# AdaBoost
# accuracy : 0.6871
# Naive Bayes
# accuracy : 0.5298
# QDA
# accuracy : 0.5563
# -------------------------------------------------
# feature_45037.pkl
# Nearest Neighbors
# accuracy : 0.8195
# Linear SVM
# accuracy : 0.6093
# RBF SVM
# accuracy : 0.8510
# Gaussian Process
# accuracy : 0.8493
# Decision Tree
# accuracy : 0.7368
# Random Forest
# accuracy : 0.7566
# Neural Net
# accuracy : 0.6788
# AdaBoost
# accuracy : 0.5265
# Naive Bayes
# accuracy : 0.6060
# QDA
# accuracy : 0.6457
# -------------------------------------------------
# feature_27457.pkl
# Nearest Neighbors
# accuracy : 0.8427
# Linear SVM
# accuracy : 0.6225
# RBF SVM
# accuracy : 0.8344
# Gaussian Process
# accuracy : 0.8328
# Decision Tree
# accuracy : 0.6987
# Random Forest
# accuracy : 0.7550
# Neural Net
# accuracy : 0.6871
# AdaBoost
# accuracy : 0.6805
# Naive Bayes
# accuracy : 0.6225
# QDA
# accuracy : 0.6457
# -------------------------------------------------
# feature_35905.pkl
# Nearest Neighbors
# accuracy : 0.9023
# Linear SVM
# accuracy : 0.6424
# RBF SVM
# accuracy : 0.9056
# Gaussian Process
# accuracy : 0.9073
# Decision Tree
# accuracy : 0.7632
# Random Forest
# accuracy : 0.7831
# Neural Net
# accuracy : 0.7252
# AdaBoost
# accuracy : 0.7384
# Naive Bayes
# accuracy : 0.6109
# QDA
# accuracy : 0.6507
# -------------------------------------------------
# feature_98691.pkl
# Nearest Neighbors
# accuracy : 0.8924
# Linear SVM
# accuracy : 0.6921
# RBF SVM
# accuracy : 0.8825
# Gaussian Process
# accuracy : 0.8974
# Decision Tree
# accuracy : 0.7219
# Random Forest
# accuracy : 0.7914
# Neural Net
# accuracy : 0.7715
# AdaBoost
# accuracy : 0.7003
# Naive Bayes
# accuracy : 0.6639
# QDA
# accuracy : 0.6871
# -------------------------------------------------
# feature_20420.pkl
# Nearest Neighbors
# accuracy : 0.8841
# Linear SVM
# accuracy : 0.6424
# RBF SVM
# accuracy : 0.8791
# Gaussian Process
# accuracy : 0.8841
# Decision Tree
# accuracy : 0.7798
# Random Forest
# accuracy : 0.7980
# Neural Net
# accuracy : 0.7119
# AdaBoost
# accuracy : 0.7417
# Naive Bayes
# accuracy : 0.6308
# QDA
# accuracy : 0.6573
# -------------------------------------------------
# feature_2734.pkl
# Nearest Neighbors
# accuracy : 0.8543
# Linear SVM
# accuracy : 0.6242
# RBF SVM
# accuracy : 0.8411
# Gaussian Process
# accuracy : 0.8560
# Decision Tree
# accuracy : 0.6838
# Random Forest
# accuracy : 0.7351
# Neural Net
# accuracy : 0.6987
# AdaBoost
# accuracy : 0.6623
# Naive Bayes
# accuracy : 0.6358
# QDA
# accuracy : 0.6705
# -------------------------------------------------
# feature_63710.pkl
# Nearest Neighbors
# accuracy : 0.8129
# Linear SVM
# accuracy : 0.5281
# RBF SVM
# accuracy : 0.8063
# Gaussian Process
# accuracy : 0.8096
# Decision Tree
# accuracy : 0.7334
# Random Forest
# accuracy : 0.6937
# Neural Net
# accuracy : 0.5795
# AdaBoost
# accuracy : 0.4901
# Naive Bayes
# accuracy : 0.5298
# QDA
# accuracy : 0.5712
# -------------------------------------------------
# feature_60132.pkl
# Nearest Neighbors
# accuracy : 0.8576
# Linear SVM
# accuracy : 0.6275
# RBF SVM
# accuracy : 0.8460
# Gaussian Process
# accuracy : 0.8609
# Decision Tree
# accuracy : 0.7351
# Random Forest
# accuracy : 0.7699
# Neural Net
# accuracy : 0.7434
# AdaBoost
# accuracy : 0.5397
# Naive Bayes
# accuracy : 0.6275
# QDA
# accuracy : 0.6639
# -------------------------------------------------
# feature_34996.pkl
# Nearest Neighbors
# accuracy : 0.8974
# Linear SVM
# accuracy : 0.6805
# RBF SVM
# accuracy : 0.9156
# Gaussian Process
# accuracy : 0.9123
# Decision Tree
# accuracy : 0.7781
# Random Forest
# accuracy : 0.8146
# Neural Net
# accuracy : 0.7235
# AdaBoost
# accuracy : 0.6540
# Naive Bayes
# accuracy : 0.6805
# QDA
# accuracy : 0.6954
# -------------------------------------------------
# feature_58591.pkl
# Nearest Neighbors
# accuracy : 0.8245
# Linear SVM
# accuracy : 0.5944
# RBF SVM
# accuracy : 0.8311
# Gaussian Process
# accuracy : 0.8328
# Decision Tree
# accuracy : 0.7285
# Random Forest
# accuracy : 0.7384
# Neural Net
# accuracy : 0.6656
# AdaBoost
# accuracy : 0.6623
# Naive Bayes
# accuracy : 0.6109
# QDA
# accuracy : 0.6358
# -------------------------------------------------
# feature_8393.pkl
# Nearest Neighbors
# accuracy : 0.8195
# Linear SVM
# accuracy : 0.6126
# RBF SVM
# accuracy : 0.8278
# /home/tonykim/Developer/CS408-CSProject/env/lib/python3.5/site-packages/sklearn/gaussian_process/gpc.py:430: UserWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([  2.02514968, -29.34692519]), 'warnflag': 2, 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 48, 'nit': 2}
#   " state: %s" % convergence_dict)
# Gaussian Process
# accuracy : 0.2682
# Decision Tree
# accuracy : 0.7583
# Random Forest
# accuracy : 0.7384
# Neural Net
# accuracy : 0.6937
# AdaBoost
# accuracy : 0.5033
# Naive Bayes
# accuracy : 0.6175
# QDA
# accuracy : 0.6374
# -------------------------------------------------
# feature_81693.pkl
# Nearest Neighbors
# accuracy : 0.8907
# Linear SVM
# accuracy : 0.6838
# RBF SVM
# accuracy : 0.8874
# Gaussian Process
# accuracy : 0.8957
# Decision Tree
# accuracy : 0.7351
# Random Forest
# accuracy : 0.8096
# Neural Net
# accuracy : 0.7467
# AdaBoost
# accuracy : 0.6043
# Naive Bayes
# accuracy : 0.6639
# QDA
# accuracy : 0.6838
# -------------------------------------------------
# feature_93052.pkl
# Nearest Neighbors
# accuracy : 0.9089
# Linear SVM
# accuracy : 0.7103
# RBF SVM
# accuracy : 0.9056
# Gaussian Process
# accuracy : 0.9139
# Decision Tree
# accuracy : 0.7997
# Random Forest
# accuracy : 0.8046
# Neural Net
# accuracy : 0.7566
# AdaBoost
# accuracy : 0.5099
# Naive Bayes
# accuracy : 0.6821
# QDA
# accuracy : 0.6970
# -------------------------------------------------
# feature_34206.pkl
# Nearest Neighbors
# accuracy : 0.8642
# Linear SVM
# accuracy : 0.6126
# RBF SVM
# accuracy : 0.8725
# Gaussian Process
# accuracy : 0.8808
# Decision Tree
# accuracy : 0.6954
# Random Forest
# accuracy : 0.7252
# Neural Net
# accuracy : 0.6639
# AdaBoost
# accuracy : 0.4834
# Naive Bayes
# accuracy : 0.5977
# QDA
# accuracy : 0.6407
# -------------------------------------------------
# feature_51880.pkl
# Nearest Neighbors
# accuracy : 0.8874
# Linear SVM
# accuracy : 0.7003
# RBF SVM
# accuracy : 0.9056
# Gaussian Process
# accuracy : 0.8891
# Decision Tree
# accuracy : 0.7467
# Random Forest
# accuracy : 0.7980
# Neural Net
# accuracy : 0.7632
# AdaBoost
# accuracy : 0.7848
# Naive Bayes
# accuracy : 0.6904
# QDA
# accuracy : 0.7368
# -------------------------------------------------
# feature_14286.pkl
# Nearest Neighbors
# accuracy : 0.8825
# Linear SVM
# accuracy : 0.5695
# RBF SVM
# accuracy : 0.8791
# Gaussian Process
# accuracy : 0.8874
# Decision Tree
# accuracy : 0.7980
# Random Forest
# accuracy : 0.7781
# Neural Net
# accuracy : 0.7185
# AdaBoost
# accuracy : 0.7533
# Naive Bayes
# accuracy : 0.5861
# QDA
# accuracy : 0.5745
# -------------------------------------------------
# feature_32224.pkl
# Nearest Neighbors
# accuracy : 0.8858
# Linear SVM
# accuracy : 0.7252
# RBF SVM
# accuracy : 0.8609
# Gaussian Process
# accuracy : 0.8758
# Decision Tree
# accuracy : 0.7930
# Random Forest
# accuracy : 0.8013
# Neural Net
# accuracy : 0.7632
# AdaBoost
# accuracy : 0.6109
# Naive Bayes
# accuracy : 0.6854
# QDA
# accuracy : 0.7169
# Done!
# CPU times: user 4h 54min 40s, sys: 5h 46min 32s, total: 10h 41min 12s
# Wall time: 56min 44s

# %%
print(best_accuracy)
print(best_model)
# Out:
# 0.9172185430463576
# feature_87086.pkl Nearest Neighbors
