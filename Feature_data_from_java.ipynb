# %%
import os
data_directory = "gait_feature_values/"
files = os.listdir(data_directory)
print(files[:1])
print(len(files))
# Out:
# ['feature_30337.txt']
# 107

# %%
import numpy as np
import pickle
from utils import *

check_dir("java_data_pickled/")

hyperparams = ['Max_threshold', 'min_stretch', 'max_stretch', 'min_step', 'max_step',
               'smooth_nl', 'smooth_nr', 'smooth_degree', 'peak_min_distance', 'outlier_m']
y_mapping = {"sober":0 , "blue":1 , "black":2}

for file in files:
    with open(data_directory+file) as f:
        print('-------------------------------------------------')
        configuration = f.readline().strip().split()
        for hyp, val in zip(hyperparams, configuration):
            print(hyp,":", val)
        features = f.readlines()
        features = [line.strip().split() for line in features]
        n = len(features)
        num_features = len(features[0]) - 1 # last value is y
        
        X = np.zeros(shape=(n, num_features))
        y = np.zeros(shape=(n,))
        
        for idx, (*x, file_name) in enumerate(features):
            color, person, phone, number, shift = file_name[:-4].split('_') # remove ".txt" and split by '_'
            X[idx] = x
            y[idx] = y_mapping[color]
        
    input_data = (X, y)
    
    with open("java_data_pickled/"+file[:-4]+".pkl", "wb") as g:
        pickle.dump(input_data, g)
# Out:
# Max_threshold : 21.07561394512427
# min_stretch : 5.7053052503769015
# max_stretch : 19.256267158008626
# min_step : 310
# max_step : 690
# smooth_nl : 22
# smooth_nr : 11
# smooth_degree : 5
# peak_min_distance : 36
# outlier_m : 2.167855485291611
# Max_threshold : 21.64785575573856
# min_stretch : 4.987516689757426
# max_stretch : 18.385488555155906
# min_step : 330
# max_step : 690
# smooth_nl : 15
# smooth_nr : 22
# smooth_degree : 7
# peak_min_distance : 34
# outlier_m : 1.9666476097060852
# Max_threshold : 21.568132486644377
# min_stretch : 3.986617995566652
# max_stretch : 19.597649913434275
# min_step : 320
# max_step : 730
# smooth_nl : 11
# smooth_nr : 18
# smooth_degree : 6
# peak_min_distance : 39
# outlier_m : 2.0303823237301875
# Max_threshold : 20.79591026637045
# min_stretch : 3.2883979944334145
# max_stretch : 19.13338681594741
# min_step : 340
# max_step : 740
# smooth_nl : 28
# smooth_nr : 24
# smooth_degree : 8
# peak_min_distance : 35
# outlier_m : 1.9831406275106658
# Max_threshold : 21.0
# min_stretch : 6.0
# max_stretch : 20.0
# min_step : 300
# max_step : 700
# smooth_nl : 20
# smooth_nr : 20
# smooth_degree : 5
# peak_min_distance : 30
# outlier_m : 2
# Max_threshold : 20.243772302961528
# min_stretch : 5.000739196390587
# max_stretch : 18.05321235052294
# min_step : 310
# max_step : 680
# smooth_nl : 13
# smooth_nr : 23
# smooth_degree : 3
# peak_min_distance : 30
# outlier_m : 2.180637969513767
# Max_threshold : 21.0
# min_stretch : 7.0
# max_stretch : 17.0
# min_step : 300
# max_step : 700
# smooth_nl : 20
# smooth_nr : 20
# smooth_degree : 5
# peak_min_distance : 30
# outlier_m : 2
# Max_threshold : 21.0
# min_stretch : 7.0
# max_stretch : 19.0
# min_step : 300
# max_step : 700
# smooth_nl : 20
# smooth_nr : 20
# smooth_degree : 5
# peak_min_distance : 30
# outlier_m : 2
# Max_threshold : 21.92090161037431
# min_stretch : 3.738062359624098
# max_stretch : 16.18983206881143
# min_step : 310
# max_step : 690
# smooth_nl : 27
# smooth_nr : 13
# smooth_degree : 3
# peak_min_distance : 37
# outlier_m : 2.1864482555751428
# Max_threshold : 21.20201965001637
# min_stretch : 3.895752636008188
# max_stretch : 19.890020852025458
# min_step : 310
# max_step : 740
# smooth_nl : 17
# smooth_nr : 19
# smooth_degree : 8
# peak_min_distance : 26
# outlier_m : 2.031279116319848
# Max_threshold : 20.804434314376447
# min_stretch : 5.765470249703082
# max_stretch : 17.08870814574747
# min_step : 310
# max_step : 690
# smooth_nl : 15
# smooth_nr : 14
# smooth_degree : 8
# peak_min_distance : 39
# outlier_m : 2.1755498641454323
# Max_threshold : 21.169891569662862
# min_stretch : 5.627869246851171
# max_stretch : 19.761626343554973
# min_step : 320
# max_step : 720
# smooth_nl : 10
# smooth_nr : 16
# smooth_degree : 8
# peak_min_distance : 27
# outlier_m : 1.9977759114095637
# Max_threshold : 21.688250723012224
# min_stretch : 3.731266051476491
# max_stretch : 17.43529870321781
# min_step : 280
# max_step : 730
# smooth_nl : 25
# smooth_nr : 23
# smooth_degree : 7
# peak_min_distance : 36
# outlier_m : 1.9730417835345948
# Max_threshold : 20.196012321193557
# min_stretch : 5.886993704625048
# max_stretch : 19.505146393298958
# min_step : 280
# max_step : 690
# smooth_nl : 26
# smooth_nr : 24
# smooth_degree : 5
# peak_min_distance : 30
# outlier_m : 2.1444701262778283
# Max_threshold : 21.15414058473564
# min_stretch : 4.95397912359712
# max_stretch : 17.47189266496971
# min_step : 340
# max_step : 700
# smooth_nl : 29
# smooth_nr : 27
# smooth_degree : 5
# peak_min_distance : 32
# outlier_m : 2.17170133801383
# Max_threshold : 21.41214845461768
# min_stretch : 4.041277518791147
# max_stretch : 17.34074447998283
# min_step : 320
# max_step : 700
# smooth_nl : 25
# smooth_nr : 16
# smooth_degree : 8
# peak_min_distance : 34
# outlier_m : 2.0684321813101274
# Max_threshold : 20.8300158330681
# min_stretch : 4.254433816394564
# max_stretch : 18.33213900442654
# min_step : 280
# max_step : 690
# smooth_nl : 14
# smooth_nr : 12
# smooth_degree : 8
# peak_min_distance : 35
# outlier_m : 1.9720142679144097
# Max_threshold : 20.039590557161468
# min_stretch : 5.512392069487184
# max_stretch : 16.43639570677853
# min_step : 290
# max_step : 710
# smooth_nl : 29
# smooth_nr : 22
# smooth_degree : 3
# peak_min_distance : 37
# outlier_m : 1.985461283171097
# Max_threshold : 21.957715091385218
# min_stretch : 3.531527589791671
# max_stretch : 19.235693684245106
# min_step : 340
# max_step : 700
# smooth_nl : 25
# smooth_nr : 19
# smooth_degree : 7
# peak_min_distance : 26
# outlier_m : 1.9275705609814993
# Max_threshold : 21.255927705677383
# min_stretch : 4.009284299418651
# max_stretch : 18.851327981547744
# min_step : 330
# max_step : 700
# smooth_nl : 18
# smooth_nr : 13
# smooth_degree : 3
# peak_min_distance : 34
# outlier_m : 2.1781453033971454
# Max_threshold : 20.31608339980874
# min_stretch : 4.439415327448549
# max_stretch : 19.566951466489265
# min_step : 340
# max_step : 710
# smooth_nl : 12
# smooth_nr : 20
# smooth_degree : 9
# peak_min_distance : 31
# outlier_m : 2.0501942905006207
# Max_threshold : 20.058595874142757
# min_stretch : 3.275566582910078
# max_stretch : 16.561735099988763
# min_step : 290
# max_step : 740
# smooth_nl : 28
# smooth_nr : 11
# smooth_degree : 9
# peak_min_distance : 28
# outlier_m : 2.1162057507111136
# Max_threshold : 20.170044541045026
# min_stretch : 4.446719266200578
# max_stretch : 16.66591819670334
# min_step : 340
# max_step : 720
# smooth_nl : 12
# smooth_nr : 14
# smooth_degree : 9
# peak_min_distance : 38
# outlier_m : 1.9307428046716382
# Max_threshold : 21.73396798596774
# min_stretch : 3.9523769997919027
# max_stretch : 17.743646090050362
# min_step : 340
# max_step : 710
# smooth_nl : 22
# smooth_nr : 29
# smooth_degree : 8
# peak_min_distance : 27
# outlier_m : 1.9791429538720895
# Max_threshold : 20.362517642586116
# min_stretch : 3.7846441845383834
# max_stretch : 19.436704423165413
# min_step : 290
# max_step : 740
# smooth_nl : 27
# smooth_nr : 13
# smooth_degree : 4
# peak_min_distance : 30
# outlier_m : 1.9183911554975526
# Max_threshold : 20.78300460271663
# min_stretch : 5.922158949936707
# max_stretch : 17.368782581100604
# min_step : 290
# max_step : 710
# smooth_nl : 17
# smooth_nr : 25
# smooth_degree : 3
# peak_min_distance : 28
# outlier_m : 1.9388070474812622
# Max_threshold : 21.55288666230876
# min_stretch : 4.98500675443779
# max_stretch : 16.156366015720128
# min_step : 320
# max_step : 690
# smooth_nl : 13
# smooth_nr : 27
# smooth_degree : 9
# peak_min_distance : 30
# outlier_m : 2.0909281013114818
# Max_threshold : 21.61378333281196
# min_stretch : 5.126742927786427
# max_stretch : 18.59107096464875
# min_step : 290
# max_step : 730
# smooth_nl : 25
# smooth_nr : 25
# smooth_degree : 7
# peak_min_distance : 31
# outlier_m : 2.010740832287961
# Max_threshold : 21.335721782489898
# min_stretch : 3.1527431013764327
# max_stretch : 19.434753828179492
# min_step : 300
# max_step : 710
# smooth_nl : 25
# smooth_nr : 10
# smooth_degree : 4
# peak_min_distance : 38
# outlier_m : 1.9804647526660921
# Max_threshold : 21.394015650393165
# min_stretch : 3.8229984815094324
# max_stretch : 19.755418780604902
# min_step : 330
# max_step : 740
# smooth_nl : 29
# smooth_nr : 16
# smooth_degree : 7
# peak_min_distance : 26
# outlier_m : 2.1877063625890956
# Max_threshold : 21.32557975452028
# min_stretch : 3.0596661906804226
# max_stretch : 17.448363819592444
# min_step : 340
# max_step : 730
# smooth_nl : 19
# smooth_nr : 19
# smooth_degree : 9
# peak_min_distance : 39
# outlier_m : 2.0843860925652646
# Max_threshold : 21.02830545051697
# min_stretch : 5.798189785925406
# max_stretch : 17.402379296948727
# min_step : 280
# max_step : 740
# smooth_nl : 19
# smooth_nr : 24
# smooth_degree : 3
# peak_min_distance : 29
# outlier_m : 1.9602776401438087
# Max_threshold : 21.89033373420807
# min_stretch : 3.4649624326383424
# max_stretch : 16.45068987392421
# min_step : 330
# max_step : 690
# smooth_nl : 12
# smooth_nr : 20
# smooth_degree : 6
# peak_min_distance : 39
# outlier_m : 2.091502691509228
# Max_threshold : 20.51564855475946
# min_stretch : 5.763175392668039
# max_stretch : 17.311868700724858
# min_step : 280
# max_step : 710
# smooth_nl : 18
# smooth_nr : 18
# smooth_degree : 3
# peak_min_distance : 28
# outlier_m : 1.9823480864029572
# Max_threshold : 21.508091343914803
# min_stretch : 5.297936607422947
# max_stretch : 17.0189551760801
# min_step : 320
# max_step : 680
# smooth_nl : 18
# smooth_nr : 16
# smooth_degree : 4
# peak_min_distance : 34
# outlier_m : 2.177501541916882
# Max_threshold : 21.393752437340034
# min_stretch : 5.570332233164779
# max_stretch : 16.32936639705514
# min_step : 300
# max_step : 730
# smooth_nl : 16
# smooth_nr : 29
# smooth_degree : 7
# peak_min_distance : 39
# outlier_m : 2.1152495670966904
# Max_threshold : 20.299920989035428
# min_stretch : 3.576883325716619
# max_stretch : 18.69350065956407
# min_step : 340
# max_step : 700
# smooth_nl : 18
# smooth_nr : 26
# smooth_degree : 5
# peak_min_distance : 26
# outlier_m : 2.1426732286502017
# Max_threshold : 20.239391010170984
# min_stretch : 5.571552820448316
# max_stretch : 18.239607240746032
# min_step : 300
# max_step : 700
# smooth_nl : 14
# smooth_nr : 16
# smooth_degree : 4
# peak_min_distance : 27
# outlier_m : 1.9214224094968628
# Max_threshold : 21.0
# min_stretch : 4.0
# max_stretch : 20.0
# min_step : 300
# max_step : 700
# smooth_nl : 20
# smooth_nr : 20
# smooth_degree : 5
# peak_min_distance : 30
# outlier_m : 2
# Max_threshold : 21.70713826122317
# min_stretch : 5.533462799087899
# max_stretch : 19.07603830413196
# min_step : 340
# max_step : 730
# smooth_nl : 17
# smooth_nr : 18
# smooth_degree : 4
# peak_min_distance : 39
# outlier_m : 1.937971594665841
# Max_threshold : 21.190996471727793
# min_stretch : 4.692248510995762
# max_stretch : 17.683343774179896
# min_step : 320
# max_step : 710
# smooth_nl : 13
# smooth_nr : 23
# smooth_degree : 7
# peak_min_distance : 26
# outlier_m : 2.123379095722755
# Max_threshold : 21.620243231898012
# min_stretch : 4.264769911805859
# max_stretch : 17.405337700761034
# min_step : 330
# max_step : 710
# smooth_nl : 27
# smooth_nr : 14
# smooth_degree : 4
# peak_min_distance : 28
# outlier_m : 1.954280206870395
# Max_threshold : 20.830258208695113
# min_stretch : 4.915646831628599
# max_stretch : 17.054783185288613
# min_step : 290
# max_step : 720
# smooth_nl : 10
# smooth_nr : 23
# smooth_degree : 7
# peak_min_distance : 35
# outlier_m : 1.988945772973844
# Max_threshold : 20.679367474479506
# min_stretch : 5.6993142319571835
# max_stretch : 19.81169976696566
# min_step : 340
# max_step : 730
# smooth_nl : 23
# smooth_nr : 27
# smooth_degree : 3
# peak_min_distance : 38
# outlier_m : 1.9920866239223796
# Max_threshold : 21.183824272818402
# min_stretch : 5.601027161499768
# max_stretch : 16.695021794735844
# min_step : 300
# max_step : 710
# smooth_nl : 11
# smooth_nr : 18
# smooth_degree : 8
# peak_min_distance : 31
# outlier_m : 2.0952441630053245
# Max_threshold : 21.388439159893064
# min_stretch : 3.488391291202099
# max_stretch : 19.803174121622515
# min_step : 310
# max_step : 740
# smooth_nl : 12
# smooth_nr : 16
# smooth_degree : 4
# peak_min_distance : 26
# outlier_m : 1.9241924095833514
# Max_threshold : 20.277993993273622
# min_stretch : 5.267381323328375
# max_stretch : 16.253042974970647
# min_step : 310
# max_step : 720
# smooth_nl : 20
# smooth_nr : 14
# smooth_degree : 7
# peak_min_distance : 39
# outlier_m : 2.1817659884986567
# Max_threshold : 20.95561695747612
# min_stretch : 5.6330909561008085
# max_stretch : 18.12319946813053
# min_step : 280
# max_step : 740
# smooth_nl : 13
# smooth_nr : 15
# smooth_degree : 6
# peak_min_distance : 31
# outlier_m : 2.0659547847470883
# Max_threshold : 20.36938659355326
# min_stretch : 3.070747655041111
# max_stretch : 17.203180920216962
# min_step : 310
# max_step : 740
# smooth_nl : 13
# smooth_nr : 23
# smooth_degree : 9
# peak_min_distance : 35
# outlier_m : 2.0386308175910126
# Max_threshold : 20.48710006812129
# min_stretch : 3.95224987835694
# max_stretch : 18.553273708745643
# min_step : 330
# max_step : 680
# smooth_nl : 19
# smooth_nr : 16
# smooth_degree : 3
# peak_min_distance : 34
# outlier_m : 1.9491242344302342
# Max_threshold : 21.0
# min_stretch : 4.0
# max_stretch : 20.0
# min_step : 300
# max_step : 700
# smooth_nl : 20
# smooth_nr : 20
# smooth_degree : 5
# peak_min_distance : 30
# outlier_m : 2
# Max_threshold : 20.536530921018702
# min_stretch : 5.560872355791188
# max_stretch : 16.169919969286116
# min_step : 290
# max_step : 720
# smooth_nl : 19
# smooth_nr : 19
# smooth_degree : 6
# peak_min_distance : 37
# outlier_m : 1.9596432424163317
# Max_threshold : 21.0
# min_stretch : 7.0
# max_stretch : 20.0
# min_step : 300
# max_step : 700
# smooth_nl : 20
# smooth_nr : 20
# smooth_degree : 5
# peak_min_distance : 30
# outlier_m : 2
# Max_threshold : 20.616899594007425
# min_stretch : 3.748332104923941
# max_stretch : 17.33263332592586
# min_step : 290
# max_step : 680
# smooth_nl : 25
# smooth_nr : 21
# smooth_degree : 8
# peak_min_distance : 28
# outlier_m : 1.9332856071211462
# Max_threshold : 20.1161777695561
# min_stretch : 4.593867821698122
# max_stretch : 19.026252993051298
# min_step : 340
# max_step : 700
# smooth_nl : 15
# smooth_nr : 26
# smooth_degree : 8
# peak_min_distance : 32
# outlier_m : 1.9701042292577695
# Max_threshold : 21.00281480299602
# min_stretch : 3.3696102994430297
# max_stretch : 19.439291177691217
# min_step : 300
# max_step : 690
# smooth_nl : 24
# smooth_nr : 10
# smooth_degree : 9
# peak_min_distance : 37
# outlier_m : 2.1490514110784327
# Max_threshold : 20.60490964808443
# min_stretch : 4.317824434131417
# max_stretch : 19.102636544183824
# min_step : 280
# max_step : 680
# smooth_nl : 14
# smooth_nr : 22
# smooth_degree : 6
# peak_min_distance : 33
# outlier_m : 2.1773127177812217
# Max_threshold : 20.899007498877754
# min_stretch : 5.404046497921791
# max_stretch : 19.684789080310384
# min_step : 290
# max_step : 710
# smooth_nl : 13
# smooth_nr : 11
# smooth_degree : 9
# peak_min_distance : 37
# outlier_m : 2.0896992248472612
# Max_threshold : 20.278517402488504
# min_stretch : 5.520422601030149
# max_stretch : 16.87742668123076
# min_step : 310
# max_step : 740
# smooth_nl : 23
# smooth_nr : 23
# smooth_degree : 8
# peak_min_distance : 29
# outlier_m : 1.9280503037446155
# Max_threshold : 21.71046308263738
# min_stretch : 3.551080425639686
# max_stretch : 18.03849071313813
# min_step : 340
# max_step : 680
# smooth_nl : 11
# smooth_nr : 11
# smooth_degree : 5
# peak_min_distance : 25
# outlier_m : 1.962903105503153
# Max_threshold : 21.519222664814784
# min_stretch : 3.1712322284568697
# max_stretch : 16.060794813678093
# min_step : 290
# max_step : 730
# smooth_nl : 25
# smooth_nr : 13
# smooth_degree : 5
# peak_min_distance : 28
# outlier_m : 2.0596477118167096
# Max_threshold : 21.04945690337296
# min_stretch : 3.9077988649394984
# max_stretch : 17.56281352615575
# min_step : 300
# max_step : 690
# smooth_nl : 24
# smooth_nr : 10
# smooth_degree : 6
# peak_min_distance : 31
# outlier_m : 2.165732824801113
# Max_threshold : 21.705292395891178
# min_stretch : 3.8788322087701936
# max_stretch : 19.365180959410484
# min_step : 290
# max_step : 680
# smooth_nl : 28
# smooth_nr : 18
# smooth_degree : 8
# peak_min_distance : 32
# outlier_m : 2.036745067408636
# Max_threshold : 20.0
# min_stretch : 4.0
# max_stretch : 20.0
# min_step : 300
# max_step : 700
# smooth_nl : 20
# smooth_nr : 20
# smooth_degree : 5
# peak_min_distance : 30
# outlier_m : 2
# Max_threshold : 21.711487834062037
# min_stretch : 5.273283738069114
# max_stretch : 17.031755559388202
# min_step : 320
# max_step : 680
# smooth_nl : 15
# smooth_nr : 28
# smooth_degree : 7
# peak_min_distance : 25
# outlier_m : 1.953294331940076
# Max_threshold : 21.30059993963974
# min_stretch : 5.923216484830952
# max_stretch : 19.111384487143543
# min_step : 280
# max_step : 730
# smooth_nl : 10
# smooth_nr : 19
# smooth_degree : 8
# peak_min_distance : 29
# outlier_m : 2.107463757123675
# Max_threshold : 20.57330611311799
# min_stretch : 5.472361835331755
# max_stretch : 16.912806313867705
# min_step : 330
# max_step : 690
# smooth_nl : 20
# smooth_nr : 15
# smooth_degree : 9
# peak_min_distance : 30
# outlier_m : 1.9599410646867539
# Max_threshold : 20.851485866435926
# min_stretch : 3.0742983498065275
# max_stretch : 17.905658377494596
# min_step : 300
# max_step : 700
# smooth_nl : 14
# smooth_nr : 24
# smooth_degree : 8
# peak_min_distance : 38
# outlier_m : 2.144111616847362
# Max_threshold : 20.188529136548265
# min_stretch : 3.3463372919832888
# max_stretch : 17.219856207087094
# min_step : 310
# max_step : 700
# smooth_nl : 27
# smooth_nr : 18
# smooth_degree : 6
# peak_min_distance : 35
# outlier_m : 2.0161847319464257
# Max_threshold : 20.841707473605684
# min_stretch : 3.6548964894207194
# max_stretch : 19.048028746289237
# min_step : 310
# max_step : 680
# smooth_nl : 10
# smooth_nr : 24
# smooth_degree : 5
# peak_min_distance : 30
# outlier_m : 1.9459434978739274
# Max_threshold : 20.4123841607061
# min_stretch : 4.878584189247228
# max_stretch : 17.03172148872583
# min_step : 290
# max_step : 690
# smooth_nl : 27
# smooth_nr : 29
# smooth_degree : 3
# peak_min_distance : 36
# outlier_m : 2.003693835980006
# Max_threshold : 21.781828909677458
# min_stretch : 3.652952649907587
# max_stretch : 19.32840225906854
# min_step : 310
# max_step : 690
# smooth_nl : 29
# smooth_nr : 25
# smooth_degree : 9
# peak_min_distance : 38
# outlier_m : 2.199624893758731
# Max_threshold : 20.554524448391298
# min_stretch : 3.493428660817236
# max_stretch : 19.206569942904004
# min_step : 310
# max_step : 710
# smooth_nl : 13
# smooth_nr : 23
# smooth_degree : 7
# peak_min_distance : 32
# outlier_m : 2.198187953624754
# Max_threshold : 20.162116276093002
# min_stretch : 3.6771135459853537
# max_stretch : 17.49983515336376
# min_step : 290
# max_step : 700
# smooth_nl : 28
# smooth_nr : 26
# smooth_degree : 6
# peak_min_distance : 34
# outlier_m : 1.9873430042768205
# Max_threshold : 20.78286116738308
# min_stretch : 5.300041087445669
# max_stretch : 18.819615723931392
# min_step : 290
# max_step : 720
# smooth_nl : 27
# smooth_nr : 23
# smooth_degree : 3
# peak_min_distance : 35
# outlier_m : 1.969726629587582
# Max_threshold : 21.905329675138596
# min_stretch : 4.363980144565997
# max_stretch : 19.829444309179134
# min_step : 300
# max_step : 690
# smooth_nl : 10
# smooth_nr : 11
# smooth_degree : 4
# peak_min_distance : 37
# outlier_m : 1.9169745700788363
# Max_threshold : 21.014945769730446
# min_stretch : 5.1068808256089255
# max_stretch : 18.31659718445584
# min_step : 300
# max_step : 720
# smooth_nl : 24
# smooth_nr : 28
# smooth_degree : 4
# peak_min_distance : 29
# outlier_m : 2.0708578025144835
# Max_threshold : 21.070075710419587
# min_stretch : 4.2578218420635
# max_stretch : 17.402714675833675
# min_step : 310
# max_step : 720
# smooth_nl : 15
# smooth_nr : 18
# smooth_degree : 5
# peak_min_distance : 39
# outlier_m : 1.9411049988195075
# Max_threshold : 20.67245024297754
# min_stretch : 5.636171418775234
# max_stretch : 16.784558323647772
# min_step : 300
# max_step : 730
# smooth_nl : 10
# smooth_nr : 26
# smooth_degree : 3
# peak_min_distance : 36
# outlier_m : 1.9479826419530453
# Max_threshold : 21.863629922271123
# min_stretch : 3.9983272919042125
# max_stretch : 19.29838847077596
# min_step : 290
# max_step : 720
# smooth_nl : 16
# smooth_nr : 27
# smooth_degree : 3
# peak_min_distance : 34
# outlier_m : 1.9199722395655399
# Max_threshold : 21.49874939196985
# min_stretch : 5.652247367917111
# max_stretch : 17.858455122244287
# min_step : 310
# max_step : 690
# smooth_nl : 17
# smooth_nr : 11
# smooth_degree : 6
# peak_min_distance : 31
# outlier_m : 2.0972102009592675
# Max_threshold : 21.246643348119292
# min_stretch : 3.1262327296950505
# max_stretch : 17.245300017826512
# min_step : 280
# max_step : 710
# smooth_nl : 28
# smooth_nr : 25
# smooth_degree : 7
# peak_min_distance : 29
# outlier_m : 2.1441235847211
# Max_threshold : 20.0057192230417
# min_stretch : 5.099274393156987
# max_stretch : 19.22395510843608
# min_step : 330
# max_step : 700
# smooth_nl : 23
# smooth_nr : 28
# smooth_degree : 5
# peak_min_distance : 27
# outlier_m : 2.100134850651006
# Max_threshold : 20.615415323210463
# min_stretch : 3.001374255316217
# max_stretch : 19.408599150001656
# min_step : 300
# max_step : 700
# smooth_nl : 28
# smooth_nr : 11
# smooth_degree : 7
# peak_min_distance : 37
# outlier_m : 1.9632725986298802
# Max_threshold : 21.769052882784184
# min_stretch : 5.627690119245855
# max_stretch : 18.669569332348257
# min_step : 340
# max_step : 690
# smooth_nl : 26
# smooth_nr : 22
# smooth_degree : 8
# peak_min_distance : 27
# outlier_m : 2.0474306681618195
# Max_threshold : 20.80287787583619
# min_stretch : 4.774116875022874
# max_stretch : 18.059160155553354
# min_step : 290
# max_step : 730
# smooth_nl : 18
# smooth_nr : 28
# smooth_degree : 4
# peak_min_distance : 34
# outlier_m : 2.145610551452328
# Max_threshold : 20.52526839226446
# min_stretch : 3.2778535648099845
# max_stretch : 19.832248556726817
# min_step : 300
# max_step : 710
# smooth_nl : 17
# smooth_nr : 22
# smooth_degree : 3
# peak_min_distance : 34
# outlier_m : 2.0118012456240932
# Max_threshold : 20.97313420325708
# min_stretch : 5.997836518075646
# max_stretch : 16.216076773830515
# min_step : 300
# max_step : 680
# smooth_nl : 25
# smooth_nr : 23
# smooth_degree : 9
# peak_min_distance : 29
# outlier_m : 1.9382999576477817
# Max_threshold : 20.100408123267083
# min_stretch : 4.925672043582788
# max_stretch : 17.674538670202097
# min_step : 300
# max_step : 680
# smooth_nl : 14
# smooth_nr : 16
# smooth_degree : 6
# peak_min_distance : 33
# outlier_m : 1.986657575478581
# Max_threshold : 21.701126553419012
# min_stretch : 3.5304603071268224
# max_stretch : 19.45647981375898
# min_step : 290
# max_step : 710
# smooth_nl : 23
# smooth_nr : 25
# smooth_degree : 7
# peak_min_distance : 31
# outlier_m : 1.9871571947822322
# Max_threshold : 20.521666852892178
# min_stretch : 5.882551146928053
# max_stretch : 17.093112277313907
# min_step : 310
# max_step : 730
# smooth_nl : 28
# smooth_nr : 22
# smooth_degree : 8
# peak_min_distance : 31
# outlier_m : 2.0956295312034294
# Max_threshold : 20.163639659518754
# min_stretch : 5.861109652346121
# max_stretch : 17.56371932141911
# min_step : 330
# max_step : 690
# smooth_nl : 28
# smooth_nr : 25
# smooth_degree : 3
# peak_min_distance : 30
# outlier_m : 2.1301314293616715
# Max_threshold : 21.116470371346434
# min_stretch : 5.598156090977782
# max_stretch : 18.23100353418512
# min_step : 320
# max_step : 690
# smooth_nl : 15
# smooth_nr : 22
# smooth_degree : 5
# peak_min_distance : 25
# outlier_m : 2.0134660578676122
# Max_threshold : 21.423424673245815
# min_stretch : 5.25142857866909
# max_stretch : 18.60899320624414
# min_step : 300
# max_step : 690
# smooth_nl : 15
# smooth_nr : 11
# smooth_degree : 3
# peak_min_distance : 36
# outlier_m : 2.026882028508292
# Max_threshold : 21.0
# min_stretch : 5.0
# max_stretch : 20.0
# min_step : 300
# max_step : 700
# smooth_nl : 20
# smooth_nr : 20
# smooth_degree : 5
# peak_min_distance : 30
# outlier_m : 2
# Max_threshold : 21.598414782328998
# min_stretch : 5.327035323902361
# max_stretch : 17.753950270199148
# min_step : 330
# max_step : 730
# smooth_nl : 27
# smooth_nr : 29
# smooth_degree : 3
# peak_min_distance : 26
# outlier_m : 1.993965743412301
# Max_threshold : 21.957517152298657
# min_stretch : 3.666073572898763
# max_stretch : 19.911959508498512
# min_step : 300
# max_step : 700
# smooth_nl : 12
# smooth_nr : 10
# smooth_degree : 9
# peak_min_distance : 39
# outlier_m : 1.935117082387171
# Max_threshold : 21.697030871758518
# min_stretch : 3.2269695309703987
# max_stretch : 17.582982115393044
# min_step : 310
# max_step : 700
# smooth_nl : 16
# smooth_nr : 25
# smooth_degree : 8
# peak_min_distance : 39
# outlier_m : 1.9633256329310407
# Max_threshold : 20.788676015253724
# min_stretch : 4.652410996973581
# max_stretch : 16.381525697305683
# min_step : 340
# max_step : 730
# smooth_nl : 20
# smooth_nr : 14
# smooth_degree : 5
# peak_min_distance : 35
# outlier_m : 2.150888548827982
# Max_threshold : 20.378826251082096
# min_stretch : 5.153605395486871
# max_stretch : 16.407206341667
# min_step : 330
# max_step : 730
# smooth_nl : 22
# smooth_nr : 27
# smooth_degree : 4
# peak_min_distance : 31
# outlier_m : 2.0570057468529663
# Max_threshold : 20.372168997676823
# min_stretch : 4.354720491735117
# max_stretch : 16.881828094145106
# min_step : 330
# max_step : 690
# smooth_nl : 12
# smooth_nr : 18
# smooth_degree : 9
# peak_min_distance : 28
# outlier_m : 1.9700960646990873
# Max_threshold : 21.907478270845
# min_stretch : 3.9174440649151236
# max_stretch : 17.498121975462936
# min_step : 330
# max_step : 730
# smooth_nl : 17
# smooth_nr : 21
# smooth_degree : 5
# peak_min_distance : 32
# outlier_m : 2.0963555027050926
# Max_threshold : 21.825163471479737
# min_stretch : 3.353378554675752
# max_stretch : 16.059706014139458
# min_step : 320
# max_step : 680
# smooth_nl : 24
# smooth_nr : 23
# smooth_degree : 3
# peak_min_distance : 26
# outlier_m : 2.0629919863423583
# Max_threshold : 20.12691734396273
# min_stretch : 5.4914305215663095
# max_stretch : 17.667386045465896
# min_step : 300
# max_step : 700
# smooth_nl : 26
# smooth_nr : 10
# smooth_degree : 6
# peak_min_distance : 39
# outlier_m : 2.030595809361003
# Max_threshold : 21.25723715758766
# min_stretch : 3.0322571361862036
# max_stretch : 19.58457117613481
# min_step : 300
# max_step : 710
# smooth_nl : 20
# smooth_nr : 19
# smooth_degree : 9
# peak_min_distance : 27
# outlier_m : 1.9632078389058258
# Max_threshold : 21.03638820722455
# min_stretch : 4.753045091300295
# max_stretch : 19.169344187186024
# min_step : 320
# max_step : 680
# smooth_nl : 25
# smooth_nr : 15
# smooth_degree : 8
# peak_min_distance : 35
# outlier_m : 1.9723509722133223
# Max_threshold : 21.473838120584794
# min_stretch : 5.86984157729823
# max_stretch : 16.887951926572192
# min_step : 280
# max_step : 700
# smooth_nl : 19
# smooth_nr : 14
# smooth_degree : 3
# peak_min_distance : 36
# outlier_m : 2.0738842248602647
